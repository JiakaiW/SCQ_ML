# %%
import scqubits as scq
import numpy as np

# %%
scq.Fluxonium(EJ=3,EC=0.5,EL=3,flux=0.5,cutoff=50).plot_wavefunction(which=[0,1,2,3])
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: xlabel='$\\varphi$', ylabel='Re $\\psi_j(\\varphi)$,  energy [GHz]'>)

# %%
scq.Fluxonium(EJ=3,EC=0.1,EL=3,flux=0.5,cutoff=50).plot_wavefunction(which=[0,1,2,3])
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: xlabel='$\\varphi$', ylabel='Re $\\psi_j(\\varphi)$,  energy [GHz]'>)

# %%
import scqubits as scq
import numpy as np
circ = scq.Circuit('''branches:
- [JJ, 1,2, 6]
- [C, 1,2, 2]
- [L, 1,2, 0.3]
''',from_file=False)

eigs = circ.eigenvals()
eigs - eigs[0]
# Out:
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# Cell In[9], line 3
#       1 import scqubits as scq
#       2 import numpy as np
# ----> 3 circ = scq.Circuit('''branches:
#       4 - [JJ, 1,2, 6]
#       5 # - [C, 1,2, 2]
#       6 # - [L, 1,2, 0.3]
#       7 ''',from_file=False)
#       9 eigs = circ.eigenvals()
#      10 eigs - eigs[0]
#
# File ~/miniconda3/envs/scqubits_latest/lib/python3.10/site-packages/scqubits/core/circuit.py:410, in Circuit.__init__(self, input_string, from_file, basis_completion, ext_basis, use_dynamic_flux_grouping, generate_noise_methods, initiate_sym_calc, truncated_dim, symbolic_param_dict, symbolic_hamiltonian, evals_method, evals_method_options, esys_method, esys_method_options)
#     406     raise Exception(
#     407         "Circuit instance must be initialized with either input_string or a symbolic hamiltonian."
#     408     )
#     409 if input_string:
# --> 410     self.from_yaml(
#     411         input_string=input_string,
#     412         from_file=from_file,
#     413         basis_completion=basis_completion,
#     414         ext_basis=ext_basis,
#     415         use_dynamic_flux_grouping=use_dynamic_flux_grouping,
#     416         generate_noise_methods=generate_noise_methods,
#     417         initiate_sym_calc=initiate_sym_calc,
#     418         truncated_dim=truncated_dim,
#     419     )
#     421 elif symbolic_hamiltonian:
#     422     if use_dynamic_flux_grouping or generate_noise_methods:
#
# File ~/miniconda3/envs/scqubits_latest/lib/python3.10/site-packages/scqubits/core/circuit.py:526, in Circuit.from_yaml(self, input_string, from_file, basis_completion, ext_basis, use_dynamic_flux_grouping, generate_noise_methods, initiate_sym_calc, truncated_dim)
#     520 if basis_completion not in ["heuristic", "canonical"]:
#     521     raise Exception(
#     522         "Invalid choice for basis_completion: must be 'heuristic' or "
#     523         "'canonical'."
#     524     )
# --> 526 symbolic_circuit = SymbolicCircuit.from_yaml(
#     527     input_string,
#     528     from_file=from_file,
#     529     basis_completion=basis_completion,
#     530     initiate_sym_calc=True,
#     531     use_dynamic_flux_grouping=use_dynamic_flux_grouping,
#     532 )
#     533 sm.init_printing(pretty_print=False, order="none")
#     534 self.is_child = False
#
# File ~/miniconda3/envs/scqubits_latest/lib/python3.10/site-packages/scqubits/core/symbolic_circuit_graph.py:878, in SymbolicCircuitGraph.from_yaml(cls, input_string, from_file, basis_completion, use_dynamic_flux_grouping, initiate_sym_calc)
#     875 input_str = remove_branchline(input_str)
#     876 input_str = strip_empty_lines(input_str)
# --> 878 parsed_branches = [
#     879     parse_code_line(code_line, branch_count)
#     880     for branch_count, code_line in enumerate(input_str.split("\n"))
#     881 ]
#     883 # find and create the nodes
#     884 nodes_list = cls._parse_nodes(parsed_branches)
#
# File ~/miniconda3/envs/scqubits_latest/lib/python3.10/site-packages/scqubits/core/symbolic_circuit_graph.py:879, in <listcomp>(.0)
#     875 input_str = remove_branchline(input_str)
#     876 input_str = strip_empty_lines(input_str)
#     878 parsed_branches = [
# --> 879     parse_code_line(code_line, branch_count)
#     880     for branch_count, code_line in enumerate(input_str.split("\n"))
#     881 ]
#     883 # find and create the nodes
#     884 nodes_list = cls._parse_nodes(parsed_branches)
#
# File ~/miniconda3/envs/scqubits_latest/lib/python3.10/site-packages/scqubits/core/circuit_input.py:223, in parse_code_line(code_line, _branch_count)
#     206 def parse_code_line(code_line: str, _branch_count):
#     207     """
#     208
#     209     Parameters
#    (...)
#     221         _branch_count: int
#     222     """
# --> 223     pp_result = BRANCHES.parse_string(code_line)
#     224     branch_type = pp_result.BRANCH_TYPE[0]
#     226     branch_type, node_idx1, node_idx2, *params, aux_params = pp_result
#
# File ~/miniconda3/envs/scqubits_latest/lib/python3.10/site-packages/pyparsing/core.py:1219, in ParserElement.parse_string(self, instring, parse_all, parseAll)
#    1216         raise
#    1218     # catch and re-raise exception from here, clearing out pyparsing internal stack trace
# -> 1219     raise exc.with_traceback(None)
#    1220 else:
#    1221     return tokens
#
# ParseException: Expected CM, found ']'  (at char 13), (line:1, col:14)

# %%
kite.__dir__()
# Out:
# ['_frozen',
#  '_sys_type',
#  '_id_str',
#  '_image_filename',
#  'evals_method',
#  'evals_method_options',
#  'esys_method',
#  'esys_method_options',
#  'is_child',
#  'symbolic_circuit',
#  'ext_basis',
#  'hierarchical_diagonalization',
#  'truncated_dim',
#  'system_hierarchy',
#  'subsystem_trunc_dims',
#  'operators_by_name',
#  'discretized_phi_range',
#  'cutoff_names',
#  '_default_grid_phi',
#  'type_of_matrices',
#  'branches',
#  'closure_branches',
#  'external_fluxes',
#  'ground_node',
#  'hamiltonian_symbolic',
#  'input_string',
#  'is_grounded',
#  'lagrangian_node_vars',
#  'lagrangian_symbolic',
#  'nodes',
#  'offset_charges',
#  'free_charges',
#  'potential_symbolic',
#  'potential_node_vars',
#  'symbolic_params',
#  'transformation_matrix',
#  'var_categories',
#  '_init_params',
#  '_out_of_sync',
#  'is_purely_harmonic',
#  '_cutoff_ext_1',
#  '_cutoff_ext_2',
#  '_cutoff_ext_3',
#  'dynamic_var_indices',
#  '_Φ1',
#  '_Φ2',
#  '_hamiltonian_sym_for_numerics',
#  'junction_potential',
#  'vars',
#  'θ1_operator',
#  'θ2_operator',
#  'θ3_operator',
#  'cosθ1_operator',
#  'cosθ2_operator',
#  'cosθ3_operator',
#  'sinθ1_operator',
#  'sinθ2_operator',
#  'sinθ3_operator',
#  'Q1_operator',
#  'Q2_operator',
#  'Q3_operator',
#  'Qs1_operator',
#  'Qs2_operator',
#  'Qs3_operator',
#  'I_operator',
#  '__module__',
#  '__doc__',
#  '__init__',
#  '_from_symbolic_hamiltonian',
#  'from_yaml',
#  '_find_branch',
#  'default_params',
#  '_clear_unnecessary_attribs',
#  'configure',
#  '_read_symbolic_hamiltonian',
#  '_configure_sym_hamiltonian',
#  '_configure',
#  'supported_noise_channels',
#  'effective_noise_channels',
#  'variable_transformation',
#  'sym_lagrangian',
#  'sym_external_fluxes',
#  'oscillator_list',
#  'qubit_list',
#  '__parameters__',
#  '_is_protocol',
#  '__subclasshook__',
#  '__abstractmethods__',
#  '_abc_impl',
#  'cutoff_ext_1',
#  'cutoff_ext_2',
#  'cutoff_ext_3',
#  'Φ1',
#  'Φ2',
#  'cutoff_ext_4',
#  'Φ3',
#  '_read_only_attributes',
#  'create',
#  'serialize',
#  'deserialize',
#  'return_root_child',
#  'return_parent_circuit',
#  '_diagonalize_purely_harmonic_hamiltonian',
#  '_transform_hamiltonian',
#  '__setattr__',
#  '__reduce__',
#  '__setstate__',
#  'cutoffs_dict',
#  '_sync_parameters_with_parent',
#  '_sync_parameters_with_subsystems',
#  '_set_sync_status_to_True',
#  'receive',
#  '_store_updated_subsystem_index',
#  '_fetch_symbolic_hamiltonian',
#  'update',
#  '_perform_internal_updates',
#  '_update_bare_esys',
#  '_is_internal_update_required',
#  '_mark_all_subsystems_as_affected',
#  '_set_property_and_update_param_vars',
#  '_set_property_and_update_ext_flux_or_charge',
#  '_set_property_and_update_cutoffs',
#  '_make_property',
#  'set_discretized_phi_range',
#  'set_and_return',
#  'get_ext_basis',
#  'discretized_grids_dict_for_vars',
#  '_check_truncation_indices',
#  '_generate_subsystems',
#  '_get_systems_and_interactions',
#  '_update_existing_subsystems',
#  '_create_new_subsystems',
#  'get_subsystem_index',
#  '_update_interactions',
#  '_operator_from_sym_expr_wrapper',
#  '_set_vars',
#  '_set_vars_no_hd',
#  'get_cutoffs',
#  '_collect_cutoff_values',
#  'hilbertdim',
#  '_kron_operator',
#  '_sparsity_adaptive',
#  '_identity_qobj',
#  '_identity',
#  'exp_i_operator',
#  '_evaluate_matrix_sawtooth_terms',
#  '_evaluate_matrix_cosine_terms',
#  '_set_harmonic_basis_osc_params',
#  '_purely_harmonic_operator_func_factory',
#  '_generate_operator_methods',
#  'offset_free_charge_values',
#  '_set_operators',
#  'is_subsystem',
#  'identity_wrap_for_hd',
#  'get_operator_by_name',
#  '_hamiltonian_for_harmonic_extended_vars',
#  '_evaluate_hamiltonian',
#  '_hamiltonian_for_purely_harmonic',
#  '_eigenvals_for_purely_harmonic',
#  'hamiltonian',
#  '_evals_calc',
#  '_esys_calc',
#  'generate_bare_eigensys',
#  'set_bare_eigensys',
#  'get_osc_param',
#  '_get_cutoff_value',
#  '__dict__',
#  '__weakref__',
#  '__slots__',
#  '__new__',
#  '__repr__',
#  '__hash__',
#  '__str__',
#  '__getattribute__',
#  '__delattr__',
#  '__lt__',
#  '__le__',
#  '__eq__',
#  '__ne__',
#  '__gt__',
#  '__ge__',
#  '__reduce_ex__',
#  '__getstate__',
#  '__init_subclass__',
#  '__format__',
#  '__sizeof__',
#  '__dir__',
#  '__class__',
#  '_contains_trigonometric_terms',
#  '_is_symbol_periodic_charge',
#  '_is_symbol_continuous_charge',
#  '_is_symbol_phase',
#  '_find_and_categorize_variable_indices',
#  '_is_expression_purely_harmonic',
#  '_constants_in_subsys',
#  '_list_of_constants_from_expr',
#  '_sym_subsystem_hamiltonian_and_interactions',
#  '_remove_constants_from_hamiltonian',
#  '_find_subsys_hamiltonian',
#  '_evaluate_symbolic_expr',
#  '_substitute_parameters',
#  '_evaluate_term',
#  '_evaluate_factor',
#  '_evaluate_sawtooth_factor',
#  '_evaluate_operator_factor',
#  '_combine_factors',
#  '_shift_harmonic_oscillator_potential',
#  '_generate_sym_potential',
#  '_is_mat_mul_replacement_necessary',
#  '_replace_mat_mul_operator',
#  '_generate_hamiltonian_sym_for_numerics',
#  '_get_eval_hamiltonian_string',
#  '_qutip_parameter_function_factory',
#  'hamiltonian_for_qutip_dynamics',
#  'print_expr_in_latex',
#  '_repr_latex_',
#  '_make_expr_human_readable',
#  'sym_potential',
#  'sym_hamiltonian',
#  'sym_interaction',
#  'operator_names_in_hamiltonian_symbolic',
#  'offset_charge_transformation',
#  '_recursive_basis_change',
#  '_basis_change_harm_osc_to_n',
#  '_basis_change_harm_osc_to_phi',
#  '_basis_change_n_to_phi',
#  '_get_var_dim_for_reshaped_wf',
#  '_dims_to_be_summed',
#  '_reshape_and_change_to_variable_basis',
#  '_basis_for_var_index',
#  '_change_to_phi_basis',
#  'generate_wf_plot_data',
#  'plot_wavefunction',
#  '_plot_wf_pdf_2D',
#  '_plot_wf_pdf_1D',
#  'potential_energy',
#  'plot_potential',
#  '__annotations__',
#  'eigenvals',
#  'eigensys',
#  'process_op',
#  'process_hamiltonian',
#  'anharmonicity',
#  'E01',
#  'matrixelement_table',
#  '_esys_for_paramval',
#  '_evals_for_paramval',
#  'get_spectrum_vs_paramvals',
#  '_compute_dispersion',
#  'get_dispersion_vs_paramvals',
#  'get_matelements_vs_paramvals',
#  'plot_evals_vs_paramvals',
#  'plot_dispersion_vs_paramvals',
#  'plot_matrixelements',
#  'plot_matelem_vs_paramvals',
#  '_quantumsystem_counter',
#  '_instance_counter',
#  '_subclasses',
#  '__del__',
#  '_autogenerate_id_str',
#  'id_str',
#  'get_initdata',
#  'get_operator_names',
#  'widget',
#  'set_params_from_gui',
#  'set_params',
#  'broadcast',
#  'filewrite',
#  'create_from_file',
#  '__protocol_attrs__',
#  '_is_runtime_protocol',
#  '__non_callable_proto_members__',
#  '__class_getitem__',
#  'Q_from_branch',
#  '_d_hamiltonian_d_function_factory',
#  '_generate_methods_d_hamiltonian_d',
#  '_transform_expr_to_new_variables',
#  '_junction_related_evaluation',
#  '_tphi_1_over_f_function_factory',
#  '_generate_tphi_1_over_f_methods',
#  '_generate_overall_tphi_cc',
#  '_generate_overall_tphi_flux',
#  '_generate_overall_tphi_ng',
#  '_t1_flux_bias_line_function_factory',
#  '_generate_t1_flux_bias_line_methods',
#  '_generate_t1_methods',
#  '_wrapper_t1_quasiparticle_tunneling',
#  '_wrapper_t1_charge_impedance',
#  '_wrapper_t1_inductive_capacitive',
#  '_generate_overall_t1_quasiparticle_tunneling',
#  '_generate_overall_t1_inductive',
#  '_generate_overall_t1_capacitive',
#  '_generate_overall_t1_charge_impedance',
#  '_generate_overall_t1_flux_bias_line',
#  'generate_noise_methods',
#  'plot_coherence_vs_paramvals',
#  'plot_t1_effective_vs_paramvals',
#  'plot_t2_effective_vs_paramvals',
#  '_effective_rate',
#  't1_effective',
#  't2_effective',
#  'transition_energy_derivative',
#  'tphi_1_over_f',
#  'tphi_1_over_f_flux',
#  'tphi_1_over_f_cc',
#  'tphi_1_over_f_ng',
#  't1',
#  't1_capacitive',
#  't1_charge_impedance',
#  't1_flux_bias_line',
#  't1_inductive',
#  't1_quasiparticle_tunneling']

# %%
fluxonium_coupler = scq.Circuit(
'''branches:
- [JJ,5,1,4.6,0.9]
- [L,1,2,0.21]
- [L,5,2,2.0]
- [C,5,2,50]
- [JJ,2,3,3,16.6]
- [L,5,3,2.0]
- [C,5,3,50]
- [L,3,4,0.21]
- [JJ,4,5,5.5,0.9]''',from_file=False, ext_basis="harmonic",
initiate_sym_calc=False, basis_completion="canonical")
system_hierarchy = [[1], [2], [3], [4]]
closure_branches = [fluxonium_coupler.branches[i] for i in [0, 4, -1]]
fluxonium_coupler.configure(closure_branches=closure_branches, system_hierarchy=system_hierarchy,
subsystem_trunc_dims = [6, 6, 6, 6])
fluxonium_coupler.Φ1 = 0.5 + 0.01768
fluxonium_coupler.Φ2 = -0.2662
fluxonium_coupler.Φ3 = -0.5 + 0.01768
fluxonium_coupler.cutoff_ext_1 = 110
fluxonium_coupler.cutoff_ext_2 = 110
fluxonium_coupler.cutoff_ext_3 = 110
fluxonium_coupler.cutoff_ext_4 = 110
eigs = fluxonium_coupler.eigenvals()
eigs - eigs[0]
# Out:
# array([0.        , 0.03559404, 0.05819727, 0.09378676, 4.39927874,
#        4.43488613])

# %%
zero_pi = scq.Circuit("""# zero-pi
branches:
- ["JJ", 1,2, EJ = 10, 20]
- ["JJ", 3,4, EJ, 20]
- ["L", 2,3, 0.008]
- ["L", 4,1, 0.008]
- ["C", 1,3, 0.02]
- ["C", 2,4, 0.02]
""",from_file=False)

# %%
zero_pi.sym_lagrangian(return_expr=True,vars_type="new",print_latex=True)
# Out:
# (25.0*\dot{θ_2}**2 + 0.00625*\dot{θ_3}**2 + 6.25625*\dot{θ_1}**2) + (-0.008*θ3**2 - 0.032*θ2**2 + EJ*cos(θ1 + θ3) + EJ*cos(θ1 + 1.0*(2πΦ_{1}) - 1.0*θ3))

# %%
zero_pi.sym_hamiltonian(return_expr=True,print_latex=True)
# Out:
# (40.0*Q3**2 + 0.03996*n1**2 + 0.03996*n_g1**2 + 0.01*Q2**2 + 0.07992*n1*n_g1) + (0.008*θ3**2 + 0.032*θ2**2 - EJ*cos(θ1 + θ3) - EJ*cos((2πΦ_{1}) + θ1 - 1.0*θ3))

# %%
zero_pi.sym_potential(return_expr=True,print_latex=True)
# Out:
# 0.008 θ_{3}^{2} + 0.032 θ_{2}^{2} - EJ \cos{\left(θ_{1} + θ_{3} \right)} - EJ \cos{\left((2πΦ_{1}) + θ_{1} - 1.0 θ_{3} \right)}
# $ 0.008 θ_{3}^{2} + 0.032 θ_{2}^{2} - EJ \cos{\left(θ_{1} + θ_{3} \right)} - EJ \cos{\left((2πΦ_{1}) + θ_{1} - 1.0 θ_{3} \right)} $

# %%
zero_pi.plot_potential(θ1=np.linspace(-np.pi, np.pi),
                       θ3=np.linspace(-6*np.pi, 6*np.pi, 200),
                       θ2 = 0.) # of
# Out:
# (<Figure size 640x480 with 2 Axes>,
#  <Axes: xlabel='$\\theta_{1}$', ylabel='$\\theta_{3}$'>)

# %%
zero_pi.plot_wavefunction(which=0, var_indices=(1,3));

# %%
for method_name in zero_pi.__dir__():
    if method_name.endswith("operator"):
        print(method_name)
# Out:
# sinθ1_operator
# cosθ1_operator
# n1_operator
# θ2_operator
# θ3_operator
# cosθ2_operator
# cosθ3_operator
# sinθ2_operator
# sinθ3_operator
# Q2_operator
# Q3_operator
# Qs2_operator
# Qs3_operator
# I_operator
# _kron_operator
# exp_i_operator
# _replace_mat_mul_operator

# %%
zero_pi.Q2_operator()
# Out:
# <9900x9900 sparse matrix of type '<class 'numpy.complex128'>'
# 	with 55440 stored elements in Compressed Sparse Column format>
